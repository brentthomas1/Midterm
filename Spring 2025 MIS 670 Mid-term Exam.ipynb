# %% [markdown]
# ### NOTICE:
#
# 1. Mechanical correctness of your python codes: your codes must be accurate
# 2. Clarity of jupyter notebook and organization of outputs:
#
# - The python codes you write must be accompanied with "comments" using # or markdown
# - All outputs must be visible in your jupyter notebook. If necessary, explain the outputs using markdown.
# - **Do not print out an entire output. Print the first five rows**
#
# 3. Formatting: **"This exam must contain K-State Honor Code "On my honor, as a student, I have neither given nor received unauthorized aid on this academic work."**
#
#  - A **grade of XF** can result from a breach of academic honesty. The F indicates failure in the course; the X indicates the reason is an Honor Pledge violation.” (http://www.k-state.edu/provost/resources/teaching/course.htm (Links to an external site.)) (See Academic Dishonesty below).
# - **Unauthorized collaboration** (including but not limited to collaborating with other students on the midterm exam is forbidden)
# - **Unauthorized aid** (including but not limited to sharing your codes with other students, receiving codes from another)
# - **Plagiarism** (including but not limited to copying words of another (on the Internet or articles) as your own)(please credit the references/sources)

# %%
# run the following syntax and sign with your full name
#input("Please sign the E-Signature (full name):")

# %% [markdown]
# # Instructions of Spring 2025 MIS 670 Mid-term Exam
#
# > Exam time: 72 hours
#
# **March 11th 12:00 AM -- March 13th 11:59 PM**
#
# 1. This is an open book open notes exam. You can use all the course materials as references. You also can Google the examples (please credit the sources), **but collaborations are forbidden and each of you should deliver different results**.
# 2. Generative AI tools are allowed to use for this exam.
# 3. No make-up exams and late submission is not allowed.
# 4. **Total points for this exam are 120.**

# %% [markdown]
# ## Travel Plan Machine
#
# > **Scraper 1: Tourist attractions scraper**
#
# >> Section 1: design the scraper (40 points)
# 1. Choose a location on Expedia (https://www.expedia.com) and scrape the tourist attractions from that place.
#     - For example: Click Things to do on the top menu, and then type the place name Tokyo, Japan → Top 10 things to do → See all (https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on)
#     - <span style="color:red"><b>Notice: each of you should think of a different location, the possibility of getting identical data is low. You should avoid to have higher similar syntax or data. Identical syntax and data will be consider plagiarism.</b></span>.
# 2. Collect at least 100 attractions (around 2 pages, 50 on each page), less than 100 attractions, will get 10 points deducted.
# 3. The dataset should include the following details: `{"Attraction_name":[], "Rating":[], "Ticket_price":[],"Free_cancellation":[], "Attraction_page":[]}`
# 4. Save your data in a Pandas dataframe.
# 5. Use df.info() to display the data information.
#
#
# <span style="color:red"><b>Hints:</b></span>
# 1. If you encounter a **captcha verification** prompting you to complete a puzzle to prove that you are not a robot, you can solve the puzzle directly on the **driver browser page.** (Use Selenium as a regualr browser). Completing one verification should allow you to access the page at least 10 times with the same IP address.
# 2. If you find it challenging to locate an element, you can select the entire project section and then search for the element from the parent node.
#     - For example, the universal xpath for titles could be `/html/body/div[2]/div[1]/div/main/div[2]/div[2]/div/section/section[2]/section[4]/div/section/div/div[2]/section/div/div[2]/section/h3` for the example link (Tokyo, Japan)
# 3. If the data does not load properly—for example, if you can't see 100 attractions—you can refresh the driver or close it and reopen the URL. Setting a longer waiting time may help the data load correctly.
# 4. `zip()` truncates to the shortest list (meaning if some elements do not exist, it will cut the entire row), you can handle this explicitly by using `itertools.zip_longest()` (check online resources for how to use this new function). This allows you to fill missing values with None or a specific string.

# %%
# Set up the environment

# %%
#Get Chrome driver

# %% [markdown]
# 1. If you need to use automation to click the "Show More" button, which Python statement you should use? (5 points)

# %% [markdown]
# [Double-click to type your answer and explain why]

# %%
# create pagination

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
#                                        Attraction_name Rating Ticket_price  \
# 0    Full Day Private Guided Photographer and Drive...  10/10       $3,040
# 1    Tokyo Sightseeing Helicopter Tour for 5 Passen...  10/10       $3,040
# 2    Snow monkeys from Tokyo: Full-Day Private trip...  10/10       $1,554
# 3      2Days Mt Fuji trip hiking transfer customizable  10/10       $1,351
# 4    【Private】Sushi Making Tokyo! Popular Sushi Cla...  10/10       $1,350
# ..                                                 ...    ...          ...
# 145  Shinjuku Ramen Crawl – Taste the Best of Ramen...   None         None
# 146  Tokyo Tsukiji Market Food and Culture Walking ...   None         None
# 147              Tsukiji Fish Market Private Food Tour   None         None
# 148  From The Sea To Plate Try Tokyo's Tsukiji Fish...   None         None
# 149       Shibuya All You Can Eat & Drink Private Tour   None         None
#
#                                     Free_cancellation  \
# ...

# %%
# basic information of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Attraction_name    150 non-null    object
#  1   Rating             69 non-null     object
#  2   Ticket_price       137 non-null    object
#  3   Free_cancellation  150 non-null    object
#  4   Attraction_page    150 non-null    object
# dtypes: object(5)
# memory usage: 6.0+ KB

# %% [markdown]
# >> Section 2: Basic data analysis (30 points)

# %% [markdown]
# 2. Drop the missing values from "Ticket_price" column. (5 points)
#    - If you don't have missing values for "Ticket_price", just list the function (use comments) that will be used for excuting this step.

# %% [markdown]
# 3. Display the 95th row in the dataframe. (5 points)

# %% [markdown]
# 4. Fill the null values in "Rating" with number 0. (3 points)

# %% [markdown]
# 5. Display the rating range of the dataset and select the top rating attractions (Rating scores >= 8). (7 points)

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
#                                       Attraction_name  Rating Ticket_price  \
# 0   Full Day Private Guided Photographer and Drive...    10.0       $3,040
# 1   Tokyo Sightseeing Helicopter Tour for 5 Passen...    10.0       $3,040
# 2   Snow monkeys from Tokyo: Full-Day Private trip...    10.0       $1,554
# 3     2Days Mt Fuji trip hiking transfer customizable    10.0       $1,351
# 4   【Private】Sushi Making Tokyo! Popular Sushi Cla...    10.0       $1,350
# ..                                                ...     ...          ...
# 63  Private Full-Day Kamakura-Enoshima Tour with B...     9.8         $449
# 64                 Retro Game Treasure Discovery Tour    10.0         $449
# 65                  Mount Fuji Escape: A Private Tour     9.8         $439
# 67  Private Sightseeing full day to Mt Fuji and Ha...    10.0         $432
# 68    Mt. Fuji and Lake Kawaguchi Day Trip with Guide    10.0         $430
#
#                                    Free_cancellation  \
# ...

# %% [markdown]
# 6. Selecting the "full-day" trips from the attraction titles. (2 points)

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
#                                        Attraction_name  Rating  Ticket_price  \
# 0    Full Day Private Guided Photographer and Drive...    10.0          3040
# 2    Snow monkeys from Tokyo: Full-Day Private trip...    10.0          1554
# 11                         Nikko Full Day Private Tour     9.0           983
# 42   Mt. Fuji, Hakone Full-Day Private Tour with En...    10.0           507
# 48   Tailored Full Day Private Experience of Kyoto ...    10.0           490
# 49   From Tokyo to Kyoto and Nara: A Captivating Fu...     9.0           490
# 50       Tokyo to Kyoto 1-Full Day Private Guided Tour     9.8           490
# 51   Kyoto Uncovered: One Full-Day Private Experien...    10.0           340
# 53   Kyoto Full Day (8 hours) Ultimate Sightseeing ...    10.0           476
# 57   Tokyo Personalized Full-day Tour Led by a Loca...     9.6           466
# 63   Private Full-Day Kamakura-Enoshima Tour with B...     9.8           449
# ...

# %% [markdown]
# 7. Display the top 10 most expansive places in the dataframe. (5 points)

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
#                                      Attraction_name  Rating  Ticket_price  \
# 0  Full Day Private Guided Photographer and Drive...    10.0          3040
# 1  Tokyo Sightseeing Helicopter Tour for 5 Passen...    10.0          3040
# 2  Snow monkeys from Tokyo: Full-Day Private trip...    10.0          1554
# 3    2Days Mt Fuji trip hiking transfer customizable    10.0          1351
# 4  【Private】Sushi Making Tokyo! Popular Sushi Cla...    10.0          1350
# 5  Nikko Sightseeing Tour (With English or Japane...    10.0          1317
# 6      Private Car Tour to Mt. Fuji Lake Kawaguchiko     9.0          1283
# 7                      Private Custom Tokyo Tour VIP    10.0          1216
# 8  Private Transfer between Tokyo and Hakuba or N...     9.4          1200
# 9  2-Day Private Tokyo MT Fuji Hakone Sightseeing...     9.2          1125
#
#                                   Free_cancellation  \
# 0  Price is $4,526 per traveler*$4,526per traveler*
# ...

# %% [markdown]
# 8. If you have a budget of 10,000 dollars for traveling to the place you selected, will it cover the attractions listed above (top 10 most expensive attractions)? (3 points)

# %% [markdown]
# > **Scraper 2: Detailed tourist attractions scraper**
#
# >> Section 1: design the scraper (30 points)
# 1. From the scraper 1, get the detailed information from the **most expensive 10 attractions**. Incorrect data collection will get 15 points deducted even with the correct syntax/code.
# 2. The data should include but not limited to the following content:`{"Attraction_name":[], "Travel_agency":[], "No.of_reviews":[], "Overview":[]}` from each attraction.
# 3. Save your data in a Pandas dataframe.
# 4. Use df.info() to display the data information. (2 points)
#
# <span style="color:red"><b>Hints:</b></span>
# 1. If you encounter a **captcha verification** prompting you to complete a puzzle to prove that you are not a robot, you can solve the puzzle directly on the **driver browser page.** (Use Selenium as a regualr browser). Completing one verification should allow you to access the page at least 10 times with the same IP address.

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
#                                      Attraction_name  \
# 0  Full Day Private Guided Photographer and Drive...
# 1  Tokyo Sightseeing Helicopter Tour for 5 Passen...
# 2  Snow monkeys from Tokyo: Full-Day Private trip...
# 3    2Days Mt Fuji trip hiking transfer customizable
# 4  【Private】Sushi Making Tokyo! Popular Sushi Cla...
# 5  Nikko Sightseeing Tour (With English or Japane...
# 6      Private Car Tour to Mt. Fuji Lake Kawaguchiko
# 7                      Private Custom Tokyo Tour VIP
# 8  Private Transfer between Tokyo and Hakuba or N...
# 9  2-Day Private Tokyo MT Fuji Hakone Sightseeing...
#
#                                     Travel_agency  \
# 0                            By Japan Experiences
# 1                               By ARILA Co.,Inc.
# 2                            By Japan Experiences
# 3                                  By Live Nippon
# 4  By Sushi Making Tokyo | Cooking Class in Japan
# 5                                    By SmartRyde
# ...

# %%
# basic info

# %% [markdown]
# >> Section 2: Data analysis (10 points)

# %% [markdown]
# 9. Among the 10 attractions, which one has the most number of reviews? (5 points)

# %% [markdown]
# 10. Groupby the Travel agencies and count how many attractions they provide for each agency. (5 points)

# %%
# This is an example output of Things to do in Tokyo
# link = "https://www.expedia.com/things-to-do/search?%2Fthings-to-do%2Fsearch%3F&d1=2024-03-16&d2=2024-03-17&endDate=2024-03-17&filter.seeAll=true&location=Tokyo%20%28and%20vicinity%29%2C%20Tokyo%20Prefecture%2C%20Japan&rid=179900&sort=RECOMMENDED&startDate=2024-03-16&swp=on"

# YOUR OUTPUT SHOULD DIFFERENT THAN MINE
# Out:
# Travel_agency
# ARILA Co.,Inc.                                 1
# Firefly Japan                                  1
# J.C.FUJI CO.,Ltd                               1
# Japan Experiences                              2
# Japan Star Travel Agency                       1
# Live Nippon                                    1
# Nippon Voyage Tours                            1
# SmartRyde                                      1
# Sushi Making Tokyo | Cooking Class in Japan    1
# Name: Attraction_name, dtype: int64

# %% [markdown]
# 11. If you need to use the entire dataset and analysis to plan your trip, please write down your plans. (5 points)

# %% [markdown]
# [Double-click and type your answers]

# %% [markdown]
# ## Excellent! You have finished the mid-term exam!
